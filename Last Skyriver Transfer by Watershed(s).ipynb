# %%
# Written by Lisa Katz (lkatz1@ucsd.edu) on 29 Dec 2022 for Python version 3.6
# to determine the time of the most recent data files transferred from
# CW3E fieldstations to the Skyriver server.

# Requirements: 
#(1) your computer is connected to ucsd vpn,
#(2) your computer has a shortcut folder to Skyriver.

# %%
# Import relevant python libraries.
import pandas as pd
from datetime import datetime, timezone
import os
import re
import time
import py

# %%
# Input the path to your shortcut folder to Skyriver.
# For example, I input <S:> (without the brackets) since 
# Skyriver is mapped to the S: drive on my laptop.
query1 = input('Input your path to Skyriver: \n')
# Out:
# Input your path to Skyriver:
# S:

# %%
# Input the code for the watershed(s) you are interested in.
query2 = input("For the Feather River watershed type 'F',\n Lake Tahoe watershed type 'L', \n Russian River watershed type 'R', \n Santa Ana Riverwatershed type 'S', \n Truckee River watershed type 'T', \n Tuolumne River watershed type 'U', \n Yampa River type 'Y',  \n Yuba River watershed type 'B', \n All Watersheds type 'A': \n")
# Out:
# For the Feather River watershed type 'F',
#  Lake Tahoe watershed type 'L',
#  Russian River watershed type 'R',
#  Santa Ana Riverwatershed type 'S',
#  Truckee River watershed type 'T',
#  Tuolumne River watershed type 'U',
#  Yampa River type 'Y',
#  Yuba River watershed type 'B',
#  All Watersheds type 'A':
# A

# %%
# To get the most recent data, find the folder with the current year.
query3 = input('What year is it? \n')
# Out:
# What year is it?
# 2023

# %%
# Since CW3E data is printed in utc time, print the current utc time for
# comparison.
dt = datetime.now(timezone.utc)
utc_time = dt.replace(tzinfo=timezone.utc)
utc_timestamp = int(utc_time.timestamp())
print('Current UTC time is: '+ time.ctime(utc_timestamp))
print('LTO = last transferred on'  + '\n')

# Search Skyriver folders and print the time 
# when the files below were last transferred on (LTO):
# (1) SurfaceMetObs data
# (2) MRR data
# (3) Disdrometer data
# (4) GPS data (Only DLA in the Yuba watershed)

if "F" in query2 or "f" in query2:
    print('Request: Feather River watershed')
    itemsSurfaceMet = ['FRC', 'POR']
    itemsMRR = []
    itemsDisdro = []
    for x in itemsSurfaceMet:
        path1 = query1+'\CW3E_DataShare\CW3E_SurfaceMetObs\\' + x + '\\' + query3
        os.chdir(path1) 
        list_of_files = os.listdir()
        list_of_files.remove('Hourly')
        largest = max(list_of_files)
        path11 = query1+'\CW3E_DataShare\CW3E_SurfaceMetObs\\' + x + '\\'+ query3 + '\\' + largest
        os.chdir(path11)
        list_of_files11 = os.listdir()
        largest11 = max(list_of_files11)
        path111 = query1+'\CW3E_DataShare\CW3E_SurfaceMetObs\\' + x + '\\'+ query3 + '\\' + largest + '\\' + largest11
        b = os.path.getctime(path111)
        c = time.ctime(b)
        print(x + ' SurfaceMetObs data LTO '+ c)
#     for xx in itemsMRR:
#         path2 = query1+'\CW3E_DataShare\CW3E_MRR\\' + xx + '\\data'
#         os.chdir(path2)
#         list_of_files = os.listdir()
#         largest = max(list_of_files)
#         path3 = query1+'\CW3E_DataShare\CW3E_MRR\\' + xx + '\\data\\' + largest
#         d = os.path.getctime(path3)
#         e = time.ctime(d)
#         print(xx + ' MRR data LTO '+ e)
#     for xxx in itemsDisdro:
#         path3 = query1+'\CW3E_DataShare\CW3E_Disdrometer\\' + xxx + '\\data'
#         os.chdir(path3)
#         list_of_files = os.listdir()
#         largest = max(list_of_files)
#         path3 = query1+'\CW3E_DataShare\CW3E_Disdrometer\\' + xxx + '\\data\\' + largest
#         f = os.path.getctime(path3)
#         g = time.ctime(f)
#         print(xxx + ' Disdrometer data LTO '+ g)

if "L" in query2 or "l" in query2:
    print('Request: Lake Tahoe watershed')
    itemsSurfaceMet = []
    itemsMRR = ['BIJ']
    itemsDisdro = []
#     for x in itemsSurfaceMet:
#         path1 = query1+'\CW3E_DataShare\CW3E_SurfaceMetObs\\' + x + '\\' + query3
#         os.chdir(path1) 
#         list_of_files = os.listdir()
#         list_of_files.remove('Hourly')
#         largest = max(list_of_files)
#         path11 = query1+'\CW3E_DataShare\CW3E_SurfaceMetObs\\' + x + '\\'+ query3 + '\\' + largest
#         os.chdir(path11)
#         list_of_files11 = os.listdir()
#         largest11 = max(list_of_files11)
#         path111 = query1+'\CW3E_DataShare\CW3E_SurfaceMetObs\\' + x + '\\'+ query3 + '\\' + largest + '\\' + largest11
#         b = os.path.getctime(path111)
#         c = time.ctime(b)
#         print(x + ' SurfaceMetObs data LTO '+ c)
    for xx in itemsMRR:
        path2 = query1+'\CW3E_DataShare\CW3E_MRR\\' + xx + '\\data'
        os.chdir(path2)
        list_of_files = os.listdir()
        largest = max(list_of_files)
        path3 = query1+'\CW3E_DataShare\CW3E_MRR\\' + xx + '\\data\\' + largest
        d = os.path.getctime(path3)
        e = time.ctime(d)
        print(xx + ' MRR data LTO '+ e)
#     for xxx in itemsDisdro:
#         path3 = query1+'\CW3E_DataShare\CW3E_Disdrometer\\' + xxx + '\\data'
#         os.chdir(path3)
#         list_of_files = os.listdir()
#         largest = max(list_of_files)
#         path3 = query1+'\CW3E_DataShare\CW3E_Disdrometer\\' + xxx + '\\data\\' + largest
#         f = os.path.getctime(path3)
#         g = time.ctime(f)
#         print(xxx + ' Disdrometer data LTO '+ g)

if "R" in query2 or "r" in query2:
    print('Request: Russian River watershed')
    itemsSurfaceMet = ['HRD', 'BCC','DRW','HDC', 'NCM', 'PVN','WDG']
    itemsMRR = ['BBY', 'PVC']
    itemsDisdro = ['HRD', 'PVC']
    for x in itemsSurfaceMet:
        path1 = query1+'\CW3E_DataShare\CW3E_SurfaceMetObs\\' + x + '\\' + query3
        os.chdir(path1) 
        list_of_files = os.listdir()
        list_of_files.remove('Hourly')
        largest = max(list_of_files)
        path11 = query1+'\CW3E_DataShare\CW3E_SurfaceMetObs\\' + x + '\\'+ query3 + '\\' + largest
        os.chdir(path11)
        list_of_files11 = os.listdir()
        largest11 = max(list_of_files11)
        path111 = query1+'\CW3E_DataShare\CW3E_SurfaceMetObs\\' + x + '\\'+ query3 + '\\' + largest + '\\' + largest11
        b = os.path.getctime(path111)
        c = time.ctime(b)
        print(x + ' SurfaceMetObs data LTO '+ c)
    for xx in itemsMRR:
        path2 = query1+'\CW3E_DataShare\CW3E_MRR\\' + xx + '\\data'
        os.chdir(path2)
        list_of_files = os.listdir()
        largest = max(list_of_files)
        path3 = query1+'\CW3E_DataShare\CW3E_MRR\\' + xx + '\\data\\' + largest
        d = os.path.getctime(path3)
        e = time.ctime(d)
        print(xx + ' MRR data LTO '+ e)
    for xxx in itemsDisdro:
        path3 = query1+'\CW3E_DataShare\CW3E_Disdrometer\\' + xxx + '\\data'
        os.chdir(path3)
        list_of_files = os.listdir()
        largest = max(list_of_files)
        path3 = query1+'\CW3E_DataShare\CW3E_Disdrometer\\' + xxx + '\\data\\' + largest
        f = os.path.getctime(path3)
        g = time.ctime(f)
        print(xxx + ' Disdrometer data LTO '+ g)
        
if "S" in query2 or "s" in query2:
    print('Request: Santa Ana River watershed')
    itemsSurfaceMet = ['YVW', 'CAT','SOD']
    itemsMRR = ['CAT','SOD']
    itemsDisdro = ['CAT','SOD']
    for x in itemsSurfaceMet:
        path1 = query1+'\CW3E_DataShare\CW3E_SurfaceMetObs\\' + x + '\\' + query3
        os.chdir(path1) 
        list_of_files = os.listdir()
        list_of_files.remove('Hourly')
        largest = max(list_of_files)
        path11 = query1+'\CW3E_DataShare\CW3E_SurfaceMetObs\\' + x + '\\'+ query3 + '\\' + largest
        os.chdir(path11)
        list_of_files11 = os.listdir()
        largest11 = max(list_of_files11)
        path111 = query1+'\CW3E_DataShare\CW3E_SurfaceMetObs\\' + x + '\\'+ query3 + '\\' + largest + '\\' + largest11
        b = os.path.getctime(path111)
        c = time.ctime(b)
        print(x + ' SurfaceMetObs data LTO '+ c)
    for xx in itemsMRR:
        path2 = query1+'\CW3E_DataShare\CW3E_MRR\\' + xx + '\\data'
        os.chdir(path2)
        list_of_files = os.listdir()
        largest = max(list_of_files)
        path3 = query1+'\CW3E_DataShare\CW3E_MRR\\' + xx + '\\data\\' + largest
        d = os.path.getctime(path3)
        e = time.ctime(d)
        print(xx + ' MRR data LTO '+ e)
    for xxx in itemsDisdro:
        path3 = query1+'\CW3E_DataShare\CW3E_Disdrometer\\' + xxx + '\\data'
        os.chdir(path3)
        list_of_files = os.listdir()
        largest = max(list_of_files)
        path3 = query1+'\CW3E_DataShare\CW3E_Disdrometer\\' + xxx + '\\data\\' + largest
        f = os.path.getctime(path3)
        g = time.ctime(f)
        print(xxx + ' Disdrometer data LTO '+ g)
        
if "T" in query2 or "t" in query2:
    print('Request: Truckee River watershed')
    itemsSurfaceMet = []
    itemsMRR = ['TRK']
    itemsDisdro = []
#     for x in itemsSurfaceMet:
#         path1 = query1+'\CW3E_DataShare\CW3E_SurfaceMetObs\\' + x + '\\' + query3
#         os.chdir(path1) 
#         list_of_files = os.listdir()
#         list_of_files.remove('Hourly')
#         largest = max(list_of_files)
#         path11 = query1+'\CW3E_DataShare\CW3E_SurfaceMetObs\\' + x + '\\'+ query3 + '\\' + largest
#         os.chdir(path11)
#         list_of_files11 = os.listdir()
#         largest11 = max(list_of_files11)
#         path111 = query1+'\CW3E_DataShare\CW3E_SurfaceMetObs\\' + x + '\\'+ query3 + '\\' + largest + '\\' + largest11
#         b = os.path.getctime(path111)
#         c = time.ctime(b)
#         print(x + ' SurfaceMetObs data LTO '+ c)
    for xx in itemsMRR:
        path2 = query1+'\CW3E_DataShare\CW3E_MRR\\' + xx + '\\data'
        os.chdir(path2)
        list_of_files = os.listdir()
        largest = max(list_of_files)
        path3 = query1+'\CW3E_DataShare\CW3E_MRR\\' + xx + '\\data\\' + largest
        d = os.path.getctime(path3)
        e = time.ctime(d)
        print(xx + ' MRR data LTO '+ e)
#     for xxx in itemsDisdro:
#         path3 = query1+'\CW3E_DataShare\CW3E_Disdrometer\\' + xxx + '\\data'
#         os.chdir(path3)
#         list_of_files = os.listdir()
#         largest = max(list_of_files)
#         path3 = query1+'\CW3E_DataShare\CW3E_Disdrometer\\' + xxx + '\\data\\' + largest
#         f = os.path.getctime(path3)
#         g = time.ctime(f)
#         print(xxx + ' Disdrometer data LTO '+ g)
        
if "U" in query2 or "u" in query2:
    print('Request: Tuolumne River watershed')
    itemsSurfaceMet = ['WPO','GPO']
    itemsMRR = ['WPO', 'GPO']
    itemsDisdro = ['WPO', 'HDM','GPO']
    for x in itemsSurfaceMet:
        path1 = query1+'\CW3E_DataShare\CW3E_SurfaceMetObs\\' + x + '\\' + query3
        os.chdir(path1) 
        list_of_files = os.listdir()
        list_of_files.remove('Hourly')
        largest = max(list_of_files)
        path11 = query1+'\CW3E_DataShare\CW3E_SurfaceMetObs\\' + x + '\\'+ query3 + '\\' + largest
        os.chdir(path11)
        list_of_files11 = os.listdir()
        largest11 = max(list_of_files11)
        path111 = query1+'\CW3E_DataShare\CW3E_SurfaceMetObs\\' + x + '\\'+ query3 + '\\' + largest + '\\' + largest11
        b = os.path.getctime(path111)
        c = time.ctime(b)
        print(x + ' SurfaceMetObs data LTO '+ c)
        print(x + ' SurfaceMetObs data LTO '+ c)
    for xx in itemsMRR:
        path2 = query1+'\CW3E_DataShare\CW3E_MRR\\' + xx + '\\data'
        os.chdir(path2)
        list_of_files = os.listdir()
        largest = max(list_of_files)
        path3 = query1+'\CW3E_DataShare\CW3E_MRR\\' + xx + '\\data\\' + largest
        d = os.path.getctime(path3)
        e = time.ctime(d)
        print(xx + ' MRR data LTO '+ e)
    for xxx in itemsDisdro:
        path3 = query1+'\CW3E_DataShare\CW3E_Disdrometer\\' + xxx + '\\data'
        os.chdir(path3)
        list_of_files = os.listdir()
        largest = max(list_of_files)
        path3 = query1+'\CW3E_DataShare\CW3E_Disdrometer\\' + xxx + '\\data\\' + largest
        f = os.path.getctime(path3)
        g = time.ctime(f)
        print(xxx + ' Disdrometer data LTO '+ g)
        
if "Y" in query2 or "y" in query2:
    print('Request: Yampa River watershed')
    itemsSurfaceMet = ['SKI']
    itemsMRR = []
    itemsDisdro = []
    for x in itemsSurfaceMet:
        path1 = query1+'\CW3E_DataShare\CW3E_SurfaceMetObs\\' + x + '\\' + query3
        os.chdir(path1) 
        list_of_files = os.listdir()
        list_of_files.remove('Hourly')
        largest = max(list_of_files)
        path11 = query1+'\CW3E_DataShare\CW3E_SurfaceMetObs\\' + x + '\\'+ query3 + '\\' + largest
        os.chdir(path11)
        list_of_files11 = os.listdir()
        largest11 = max(list_of_files11)
        path111 = query1+'\CW3E_DataShare\CW3E_SurfaceMetObs\\' + x + '\\'+ query3 + '\\' + largest + '\\' + largest11
        b = os.path.getctime(path111)
        c = time.ctime(b)
        print(x + ' SurfaceMetObs data LTO '+ c)
#     for xx in itemsMRR:
#         path2 = query1+'\CW3E_DataShare\CW3E_MRR\\' + xx + '\\data'
#         os.chdir(path2)
#         list_of_files = os.listdir()
#         largest = max(list_of_files)
#         path3 = query1+'\CW3E_DataShare\CW3E_MRR\\' + xx + '\\data\\' + largest
#         d = os.path.getctime(path3)
#         e = time.ctime(d)
#         print(xx + ' MRR data LTO '+ e)
#     for xxx in itemsDisdro:
#         path3 = query1+'\CW3E_DataShare\CW3E_Disdrometer\\' + xxx + '\\data'
#         os.chdir(path3)
#         list_of_files = os.listdir()
#         largest = max(list_of_files)
#         path3 = query1+'\CW3E_DataShare\CW3E_Disdrometer\\' + xxx + '\\data\\' + largest
#         f = os.path.getctime(path3)
#         g = time.ctime(f)
#         print(xxx + ' Disdrometer data LTO '+ g)
        
if "B" in query2 or "b" in query2:
    print('Request: Yuba River watershed')
    itemsSurfaceMet = ['BVS', 'DLA','NBB', 'SKY'] #LBH
    itemsMRR = ['DLA','NBB',]
    itemsDisdro = ['DLA','LBH','NBB']
    itemsGPS = ['DLA']
    for x in itemsSurfaceMet:
        path1 = query1+'\CW3E_DataShare\CW3E_SurfaceMetObs\\' + x + '\\' + query3
        os.chdir(path1) 
        list_of_files = os.listdir()
        list_of_files.remove('Hourly')
        largest = max(list_of_files)
        path11 = query1+'\CW3E_DataShare\CW3E_SurfaceMetObs\\' + x + '\\'+ query3 + '\\' + largest
        os.chdir(path11)
        list_of_files11 = os.listdir()
        largest11 = max(list_of_files11)
        path111 = query1+'\CW3E_DataShare\CW3E_SurfaceMetObs\\' + x + '\\'+ query3 + '\\' + largest + '\\' + largest11
        b = os.path.getctime(path111)
        c = time.ctime(b)
        print(x + ' SurfaceMetObs data LTO '+ c)
    for xx in itemsMRR:
        path2 = query1+'\CW3E_DataShare\CW3E_MRR\\' + xx + '\\data'
        os.chdir(path2)
        list_of_files = os.listdir()
        largest = max(list_of_files)
        path3 = query1+'\CW3E_DataShare\CW3E_MRR\\' + xx + '\\data\\' + largest
        d = os.path.getctime(path3)
        e = time.ctime(d)
        print(xx + ' MRR data LTO '+ e)
    for xxx in itemsDisdro:
        path3 = query1+'\CW3E_DataShare\CW3E_Disdrometer\\' + xxx + '\\data'
        os.chdir(path3)
        list_of_files = os.listdir()
        largest = max(list_of_files)
        path3 = query1+'\CW3E_DataShare\CW3E_Disdrometer\\' + xxx + '\\data\\' + largest
        f = os.path.getctime(path3)
        g = time.ctime(f)
        print(xxx + ' Disdrometer data LTO '+ g)
    for xxxx in itemsGPS:
        path4 = query1+'\CW3E_DataShare\CW3E_GPS\\' + xxxx
        h = os.path.getctime(path4)
        i = time.ctime(h)
        print(xxxx + ' Disdrometer data LTO '+ i)
        
        
if "A" in query2 or "a" in query2:
    print('[ Request: All Watersheds]\n')
    print('Feather River watershed:')
    itemsSurfaceMet = ['FRC', 'POR']
    itemsMRR = []
    itemsDisdro = []
    for x in itemsSurfaceMet:
        path1 = query1+'\CW3E_DataShare\CW3E_SurfaceMetObs\\' + x + '\\' + query3
        os.chdir(path1) 
        list_of_files = os.listdir()
        list_of_files.remove('Hourly')
        largest = max(list_of_files)
        path11 = query1+'\CW3E_DataShare\CW3E_SurfaceMetObs\\' + x + '\\'+ query3 + '\\' + largest
        os.chdir(path11)
        list_of_files11 = os.listdir()
        largest11 = max(list_of_files11)
        path111 = query1+'\CW3E_DataShare\CW3E_SurfaceMetObs\\' + x + '\\'+ query3 + '\\' + largest + '\\' + largest11
        b = os.path.getctime(path111)
        c = time.ctime(b)
        print(x + ' SurfaceMetObs data LTO '+ c)
    print('\n')
#     for xx in itemsMRR:
#         path2 = query1+'\CW3E_DataShare\CW3E_MRR\\' + xx + '\\data'
#         os.chdir(path2)
#         list_of_files = os.listdir()
#         largest = max(list_of_files)
#         path3 = query1+'\CW3E_DataShare\CW3E_MRR\\' + xx + '\\data\\' + largest
#         d = os.path.getctime(path3)
#         e = time.ctime(d)
#         print(xxx + ' MRR data LTO '+ e)
#     for xxx in itemsDisdro:
#         path3 = query1+'\CW3E_DataShare\CW3E_Disdrometer\\' + xxx + '\\data'
#         os.chdir(path3)
#         list_of_files = os.listdir()
#         largest = max(list_of_files)
#         path3 = query1+'\CW3E_DataShare\CW3E_Disdrometer\\' + xxx + '\\data\\' + largest
#         f = os.path.getctime(path3)
#         g = time.ctime(f)
#         print(xxx + ' Disdrometer data LTO '+ g)


    print('Lake Tahoe watershed:')
    itemsSurfaceMet = []
    itemsMRR = ['BIJ']
    itemsDisdro = []
#     for x in itemsSurfaceMet:
#         path1 = query1+'\CW3E_DataShare\CW3E_SurfaceMetObs\\' + x + '\\' + query3
#         os.chdir(path1) 
#         list_of_files = os.listdir()
#         list_of_files.remove('Hourly')
#         largest = max(list_of_files)
#         path11 = query1+'\CW3E_DataShare\CW3E_SurfaceMetObs\\' + x + '\\'+ query3 + '\\' + largest
#         os.chdir(path11)
#         list_of_files11 = os.listdir()
#         largest11 = max(list_of_files11)
#         path111 = query1+'\CW3E_DataShare\CW3E_SurfaceMetObs\\' + x + '\\'+ query3 + '\\' + largest + '\\' + largest11
#         b = os.path.getctime(path111)
#         c = time.ctime(b)
#         print(x + ' SurfaceMetObs data LTO '+ c)
    for xx in itemsMRR:
        path2 = query1+'\CW3E_DataShare\CW3E_MRR\\' + xx + '\\data'
        os.chdir(path2)
        list_of_files = os.listdir()
        largest = max(list_of_files)
        path3 = query1+'\CW3E_DataShare\CW3E_MRR\\' + xx + '\\data\\' + largest
        d = os.path.getctime(path3)
        e = time.ctime(d)
        print(xx + ' MRR data LTO '+ e)
    print('\n')
#     for xxx in itemsDisdro:
#         path3 = query1+'\CW3E_DataShare\CW3E_Disdrometer\\' + xxx + '\\data'
#         os.chdir(path3)
#         list_of_files = os.listdir()
#         largest = max(list_of_files)
#         path3 = query1+'\CW3E_DataShare\CW3E_Disdrometer\\' + xxx + '\\data\\' + largest
#         f = os.path.getctime(path3)
#         g = time.ctime(f)
#         print(xxx + ' Disdrometer data LTO '+ g)

    print('Russian River watershed:')
    itemsSurfaceMet = ['HRD', 'BCC','DRW','HDC', 'NCM', 'PVN','WDG']
    itemsMRR = ['BBY', 'PVC']
    itemsDisdro = ['HRD', 'PVC']
    for x in itemsSurfaceMet:
        path1 = query1+'\CW3E_DataShare\CW3E_SurfaceMetObs\\' + x + '\\' + query3
        os.chdir(path1) 
        list_of_files = os.listdir()
        list_of_files.remove('Hourly')
        largest = max(list_of_files)
        path11 = query1+'\CW3E_DataShare\CW3E_SurfaceMetObs\\' + x + '\\'+ query3 + '\\' + largest
        os.chdir(path11)
        list_of_files11 = os.listdir()
        largest11 = max(list_of_files11)
        path111 = query1+'\CW3E_DataShare\CW3E_SurfaceMetObs\\' + x + '\\'+ query3 + '\\' + largest + '\\' + largest11
        b = os.path.getctime(path111)
        c = time.ctime(b)
        print(x + ' SurfaceMetObs data LTO '+ c)
        print(x + ' SurfaceMetObs data LTO '+ c)
    for xx in itemsMRR:
        path2 = query1+'\CW3E_DataShare\CW3E_MRR\\' + xx + '\\data'
        os.chdir(path2)
        list_of_files = os.listdir()
        largest = max(list_of_files)
        path3 = query1+'\CW3E_DataShare\CW3E_MRR\\' + xx + '\\data\\' + largest
        d = os.path.getctime(path3)
        e = time.ctime(d)
        print(xx + ' MRR data LTO '+ e)
    for xxx in itemsDisdro:
        path3 = query1+'\CW3E_DataShare\CW3E_Disdrometer\\' + xxx + '\\data'
        os.chdir(path3)
        list_of_files = os.listdir()
        largest = max(list_of_files)
        path3 = query1+'\CW3E_DataShare\CW3E_Disdrometer\\' + xxx + '\\data\\' + largest
        f = os.path.getctime(path3)
        g = time.ctime(f)
        print(xxx + ' Disdrometer data LTO '+ g)
    print('\n')
        
    print('Santa Ana River watershed:')
    itemsSurfaceMet = ['YVW', 'CAT','SOD']
    itemsMRR = ['CAT','SOD']
    itemsDisdro = ['CAT','SOD']
    for x in itemsSurfaceMet:
        path1 = query1+'\CW3E_DataShare\CW3E_SurfaceMetObs\\' + x + '\\' + query3
        os.chdir(path1) 
        list_of_files = os.listdir()
        list_of_files.remove('Hourly')
        largest = max(list_of_files)
        path11 = query1+'\CW3E_DataShare\CW3E_SurfaceMetObs\\' + x + '\\'+ query3 + '\\' + largest
        os.chdir(path11)
        list_of_files11 = os.listdir()
        largest11 = max(list_of_files11)
        path111 = query1+'\CW3E_DataShare\CW3E_SurfaceMetObs\\' + x + '\\'+ query3 + '\\' + largest + '\\' + largest11
        b = os.path.getctime(path111)
        c = time.ctime(b)
        print(x + ' SurfaceMetObs data LTO '+ c)
        print(x + ' SurfaceMetObs data LTO '+ c)
    for xx in itemsMRR:
        path2 = query1+'\CW3E_DataShare\CW3E_MRR\\' + xx + '\\data'
        os.chdir(path2)
        list_of_files = os.listdir()
        largest = max(list_of_files)
        path3 = query1+'\CW3E_DataShare\CW3E_MRR\\' + xx + '\\data\\' + largest
        d = os.path.getctime(path3)
        e = time.ctime(d)
        print(xx + ' MRR data LTO '+ e)
    for xxx in itemsDisdro:
        path3 = query1+'\CW3E_DataShare\CW3E_Disdrometer\\' + xxx + '\\data'
        os.chdir(path3)
        list_of_files = os.listdir()
        largest = max(list_of_files)
        path3 = query1+'\CW3E_DataShare\CW3E_Disdrometer\\' + xxx + '\\data\\' + largest
        f = os.path.getctime(path3)
        g = time.ctime(f)
        print(xxx + ' Disdrometer data LTO '+ g)
    print('\n')
        
    print('Truckee River watershed:')
    itemsSurfaceMet = []
    itemsMRR = ['TRK']
    itemsDisdro = []
#     for x in itemsSurfaceMet:
#         path1 = query1+'\CW3E_DataShare\CW3E_SurfaceMetObs\\' + x + '\\' + query3
#         os.chdir(path1) 
#         list_of_files = os.listdir()
#         list_of_files.remove('Hourly')
#         largest = max(list_of_files)
#         path11 = query1+'\CW3E_DataShare\CW3E_SurfaceMetObs\\' + x + '\\'+ query3 + '\\' + largest
#         os.chdir(path11)
#         list_of_files11 = os.listdir()
#         largest11 = max(list_of_files11)
#         path111 = query1+'\CW3E_DataShare\CW3E_SurfaceMetObs\\' + x + '\\'+ query3 + '\\' + largest + '\\' + largest11
#         b = os.path.getctime(path111)
#         c = time.ctime(b)
#         print(x + ' SurfaceMetObs data LTO '+ c)
    for xx in itemsMRR:
        path2 = query1+'\CW3E_DataShare\CW3E_MRR\\' + xx + '\\data'
        os.chdir(path2)
        list_of_files = os.listdir()
        largest = max(list_of_files)
        path3 = query1+'\CW3E_DataShare\CW3E_MRR\\' + xx + '\\data\\' + largest
        d = os.path.getctime(path3)
        e = time.ctime(d)
        print(xx + ' MRR data LTO '+ e)
    print('\n')
#     for xxx in itemsDisdro:
#         path3 = query1+'\CW3E_DataShare\CW3E_Disdrometer\\' + xxx + '\\data'
#         os.chdir(path3)
#         list_of_files = os.listdir()
#         largest = max(list_of_files)
#         path3 = query1+'\CW3E_DataShare\CW3E_Disdrometer\\' + xxx + '\\data\\' + largest
#         f = os.path.getctime(path3)
#         g = time.ctime(f)
#         print(xxx + ' Disdrometer data LTO '+ g)
        
    print('Tuolumne River watershed:')
    itemsSurfaceMet = ['WPO','GPO']
    itemsMRR = ['WPO', 'GPO']
    itemsDisdro = ['WPO', 'HDM','GPO']
    for x in itemsSurfaceMet:
        path1 = query1+'\CW3E_DataShare\CW3E_SurfaceMetObs\\' + x + '\\' + query3
        os.chdir(path1) 
        list_of_files = os.listdir()
        list_of_files.remove('Hourly')
        largest = max(list_of_files)
        path11 = query1+'\CW3E_DataShare\CW3E_SurfaceMetObs\\' + x + '\\'+ query3 + '\\' + largest
        os.chdir(path11)
        list_of_files11 = os.listdir()
        largest11 = max(list_of_files11)
        path111 = query1+'\CW3E_DataShare\CW3E_SurfaceMetObs\\' + x + '\\'+ query3 + '\\' + largest + '\\' + largest11
        b = os.path.getctime(path111)
        c = time.ctime(b)
        print(x + ' SurfaceMetObs data LTO '+ c)
    for xx in itemsMRR:
        path2 = query1+'\CW3E_DataShare\CW3E_MRR\\' + xx + '\\data'
        os.chdir(path2)
        list_of_files = os.listdir()
        largest = max(list_of_files)
        path3 = query1+'\CW3E_DataShare\CW3E_MRR\\' + xx + '\\data\\' + largest
        d = os.path.getctime(path3)
        e = time.ctime(d)
        print(xx + ' MRR data LTO '+ e)
    for xxx in itemsDisdro:
        path3 = query1+'\CW3E_DataShare\CW3E_Disdrometer\\' + xxx + '\\data'
        os.chdir(path3)
        list_of_files = os.listdir()
        largest = max(list_of_files)
        path3 = query1+'\CW3E_DataShare\CW3E_Disdrometer\\' + xxx + '\\data\\' + largest
        f = os.path.getctime(path3)
        g = time.ctime(f)
        print(xxx + ' Disdrometer data LTO '+ g)
    print('\n')   
    print('Yampa River watershed:')
    itemsSurfaceMet = ['SKI']
    itemsMRR = []
    itemsDisdro = []
    for x in itemsSurfaceMet:
        path1 = query1+'\CW3E_DataShare\CW3E_SurfaceMetObs\\' + x + '\\' + query3
        os.chdir(path1) 
        list_of_files = os.listdir()
        list_of_files.remove('Hourly')
        largest = max(list_of_files)
        path11 = query1+'\CW3E_DataShare\CW3E_SurfaceMetObs\\' + x + '\\'+ query3 + '\\' + largest
        os.chdir(path11)
        list_of_files11 = os.listdir()
        largest11 = max(list_of_files11)
        path111 = query1+'\CW3E_DataShare\CW3E_SurfaceMetObs\\' + x + '\\'+ query3 + '\\' + largest + '\\' + largest11
        b = os.path.getctime(path111)
        c = time.ctime(b)
        print(x + ' SurfaceMetObs data LTO '+ c)
    print('\n')
#     for xx in itemsMRR:
#         path2 = query1+'\CW3E_DataShare\CW3E_MRR\\' + xx + '\\data'
#         os.chdir(path2)
#         list_of_files = os.listdir()
#         largest = max(list_of_files)
#         path3 = query1+'\CW3E_DataShare\CW3E_MRR\\' + xx + '\\data\\' + largest
#         d = os.path.getctime(path3)
#         e = time.ctime(d)
#         print(xx + ' MRR data LTO '+ e)
#     for xxx in itemsDisdro:
#         path3 = query1+'\CW3E_DataShare\CW3E_Disdrometer\\' + xxx + '\\data'
#         os.chdir(path3)
#         list_of_files = os.listdir()
#         largest = max(list_of_files)
#         path3 = query1+'\CW3E_DataShare\CW3E_Disdrometer\\' + xxx + '\\data\\' + largest
#         f = os.path.getctime(path3)
#         g = time.ctime(f)
#         print(xxx + ' Disdrometer data LTO '+ g)
        
    print('Yuba River watershed:')
    itemsSurfaceMet = ['BVS', 'DLA','NBB', 'SKY']
    itemsMRR = ['DLA','NBB',]
    itemsDisdro = ['DLA','NBB']
    itemsGPS = ['DLA']
    for x in itemsSurfaceMet:
        path1 = query1+'\CW3E_DataShare\CW3E_SurfaceMetObs\\' + x + '\\' + query3
        os.chdir(path1) 
        list_of_files = os.listdir()
        list_of_files.remove('Hourly')
        largest = max(list_of_files)
        path11 = query1+'\CW3E_DataShare\CW3E_SurfaceMetObs\\' + x + '\\'+ query3 + '\\' + largest
        os.chdir(path11)
        list_of_files11 = os.listdir()
        largest11 = max(list_of_files11)
        path111 = query1+'\CW3E_DataShare\CW3E_SurfaceMetObs\\' + x + '\\'+ query3 + '\\' + largest + '\\' + largest11
        b = os.path.getctime(path111)
        c = time.ctime(b)
        print(x + ' SurfaceMetObs data LTO '+ c)
    for xx in itemsMRR:
        path2 = query1+'\CW3E_DataShare\CW3E_MRR\\' + xx + '\\data'
        os.chdir(path2)
        list_of_files = os.listdir()
        largest = max(list_of_files)
        path3 = query1+'\CW3E_DataShare\CW3E_MRR\\' + xx + '\\data\\' + largest
        d = os.path.getctime(path3)
        e = time.ctime(d)
        print(xx + ' MRR data LTO '+ e)
    for xxx in itemsDisdro:
        path3 = query1+'\CW3E_DataShare\CW3E_Disdrometer\\' + xxx + '\\data'
        os.chdir(path3)
        list_of_files = os.listdir()
        largest = max(list_of_files)
        path3 = query1+'\CW3E_DataShare\CW3E_Disdrometer\\' + xxx + '\\data\\' + largest
        f = os.path.getctime(path3)
        g = time.ctime(f)
        print(xxx + ' Disdrometer data LTO '+ g)
    for xxxx in itemsGPS:
        path4 = query1+'\CW3E_DataShare\CW3E_GPS\\' + xxxx
        h = os.path.getctime(path4)
        i = time.ctime(h)
        print(xxxx + ' GPS data LTO '+ i)
# Out:
# Current UTC time is: Tue Jan  3 10:29:24 2023
# LTO = last transferred on
#
# [ Request: All Watersheds]
#
# Feather River watershed:
# FRC SurfaceMetObs data LTO Tue Jan  3 10:17:58 2023
# POR SurfaceMetObs data LTO Tue Jan  3 10:17:58 2023
#
#
# Lake Tahoe watershed:
# BIJ MRR data LTO Sat Dec 31 16:50:09 2022
#
#
# Russian River watershed:
# HRD SurfaceMetObs data LTO Tue Jan  3 10:17:58 2023
# HRD SurfaceMetObs data LTO Tue Jan  3 10:17:58 2023
# BCC SurfaceMetObs data LTO Tue Jan  3 10:17:58 2023
# BCC SurfaceMetObs data LTO Tue Jan  3 10:17:58 2023
# DRW SurfaceMetObs data LTO Tue Jan  3 10:17:58 2023
# DRW SurfaceMetObs data LTO Tue Jan  3 10:17:58 2023
# HDC SurfaceMetObs data LTO Tue Jan  3 10:17:58 2023
# HDC SurfaceMetObs data LTO Tue Jan  3 10:17:58 2023
# NCM SurfaceMetObs data LTO Tue Jan  3 10:17:58 2023
# NCM SurfaceMetObs data LTO Tue Jan  3 10:17:58 2023
# PVN SurfaceMetObs data LTO Tue Jan  3 10:17:58 2023
# PVN SurfaceMetObs data LTO Tue Jan  3 10:17:58 2023
# ...
